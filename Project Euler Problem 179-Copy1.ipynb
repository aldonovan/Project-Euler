# %%
import math

#Better idea: Let's store the prime factorizations of past numbers and then use it to factor following numbers

primes = [2, 3, 5]

#Stores prior prime factorizations
factorDict = {2: ([2], [1]), 3:([3], [1]), 4: ([2], [2]), 5: ([5], [1])}


#Fix bug starting at 18
def calculateFactors(tup1, tup2, num):
    x = 0
    while(x < len(tup2[0])):
        if(tup2[0][x] in tup1[0]):
            tup1[1][tup1[0].index(tup2[0][x])] = tup1[1][tup1[0].index(tup2[0][x])] + tup2[1][x]
        else:
            tup1[0].append(tup2[0][x])
            tup1[1].append(tup2[1][x])   
        x = x + 1
    return tup1


def numFactors(x):
    initialNumber = x
    primeFactors=[]
    powers=[]
    factorTup = ()
    #Find prime factorization
    xPrime = True
    if(x%2 == 0):
        primeFactors.append(2)
        powers.append(1)
        x = x/2
        factorTup = calculateFactors((primeFactors, powers), factorDict[x], initialNumber)
        x = 1
        xPrime = False
    i = 1
    while(i < len(primes) and primes[i] <= math.sqrt(x)):
        if(x%(primes[i]) == 0):
            primeFactors.append(primes[i])
            powers.append(1)
            x = x/(primes[i])
            factorTup = calculateFactors((primeFactors, powers), factorDict[x], initialNumber)
            xPrime = False
            break
        i = i + 1       
    if(xPrime):
        factorTup = ([x],[1])
        
    factorDict[initialNumber] = factorTup
    return calcFactors(factorTup)

def calcFactors(factorization):
    numFactors = 1
    for i in range(len(factorization[0])):
        numFactors = numFactors * (factorization[1][i]+1)
    if(numFactors == 2):
        primes.append(factorization[0][0])
    return numFactors
    

desiredNumber = 1
numCurrFactors = 1
for i in range(5, 10000000):
    numNextFactors = numFactors(i+1)
    if(i%100000 == 0):
        print(i)
    if(numCurrFactors == numNextFactors):
        desiredNumber = desiredNumber + 1
    numCurrFactors = numNextFactors
print(desiredNumber)
# Out:
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
